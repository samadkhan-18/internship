# %% [markdown]
# <a href="https://colab.research.google.com/github/samadkhan-18/internship/blob/main/sam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code and audio.
#
# **How to get started**
# *  Go to <a href="https://aistudio.google.com/">Google AI Studio</a> and log in with your Google Account.
# *  <a href="https://aistudio.google.com/app/apikey">Create an API key</a>.
# * Use a quickstart for <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb">Python</a> or call the REST API using <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb">curl</a>.
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb">multimodal outputs</a>, mixing text and images in an iterative way.
# *  Discover the <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb">multimodal Live API</a> &#40;demo <a href="https://aistudio.google.com/live">here</a>&#41;.
# *  Learn how to <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb&quot;">analyse images and detect items in your pictures</a> using Gemini &#40;bonus, there's a <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb">3D version</a> as well!&#41;.
# *  Unlock the power of the <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb">Gemini thinking model</a>, capable of solving complex tasks with its inner thoughts.
#
# **Explore complex use cases**
# *  Use <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb">Gemini grounding capabilities</a> to create a report on a company based on what the model can find on the Internet.
# *  Extract <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb">invoices and form data from PDFs</a> in a structured way.
# *  Create <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb">illustrations based on a whole book</a> using Gemini large context window and Imagen.
#
# To learn more, take a look at the <a href="https://github.com/google-gemini/cookbook">Gemini cookbook</a> or visit the <a href="https://ai.google.dev/docs/">Gemini API documentation</a>.

# %%
import pandas as pd
df=pd.read_csv("/content/big_bazaar_sales.csv")
df
# Out:
#     Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0       BB1001     CUST583    Male   21  Ahmedabad        Household
# 1       BB1002     CUST766    Male   41  Bangalore        Furniture
# 2       BB1003     CUST285    Male   64      Surat        Groceries
# 3       BB1004     CUST381  Female   30     Nagpur      Electronics
# 4       BB1005     CUST979    Male   63       Pune           Sports
# ..         ...         ...     ...  ...        ...              ...
# 995     BB1996     CUST332  Female   36    Lucknow     Toys & Games
# 996     BB1997     CUST327    Male   36     Bhopal          Apparel
# 997     BB1998     CUST709    Male   55     Nagpur        Furniture
# 998     BB1999     CUST943    Male   45  Hyderabad       Stationery
# 999     BB2000     CUST799    Male   45      Thane          Kitchen
#
#       Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0          Doormat        10          224.45       2244.50           Cash
# 1            Table         2          270.05        540.10    Credit Card
# 2           Paneer         9          436.59       3929.31            UPI
# 3       Power Bank         6          254.36       1526.16         Wallet
# 4        Dumbbells         2          262.23        524.46         Wallet
# ..             ...       ...             ...           ...            ...
# 995     Board Game         7          474.27       3319.89            UPI
# 996       Leggings         7          437.77       3064.39         Wallet
# 997  Plastic Stool         1          278.20        278.20           Cash
# 998         Marker         8          260.94       2087.52         Wallet
# 999       Utensils         7           89.96        629.72           Cash
#
#     Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 0         2025-05-06                10       2020.05               No
# 1         2025-04-04                15        459.08              Yes
# 2         2024-12-01                20       3143.45               No
# 3         2024-10-03                15       1297.24               No
# 4         2025-01-04                 5        498.24              Yes
# ..               ...               ...           ...              ...
# 995       2024-07-16                20       2655.91               No
# 996       2024-08-16                 5       2911.17              Yes
# 997       2025-06-06                20        222.56              Yes
# 998       2025-06-13                10       1878.77              Yes
# 999       2024-12-23                10        566.75               No
#
# [1000 rows x 15 columns]

# %%
df.tail(10)
# Out:
#     Invoice_ID Customer_ID  Gender  Age        City Product_Category  \
# 990     BB1991     CUST364    Male   32       Delhi           Beauty
# 991     BB1992     CUST318    Male   36       Thane          Apparel
# 992     BB1993     CUST340    Male   33      Nagpur           Beauty
# 993     BB1994     CUST504  Female   41      Jaipur           Sports
# 994     BB1995     CUST254    Male   43  Chandigarh        Furniture
# 995     BB1996     CUST332  Female   36     Lucknow     Toys & Games
# 996     BB1997     CUST327    Male   36      Bhopal          Apparel
# 997     BB1998     CUST709    Male   55      Nagpur        Furniture
# 998     BB1999     CUST943    Male   45   Hyderabad       Stationery
# 999     BB2000     CUST799    Male   45       Thane          Kitchen
#
#       Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 990     Face Cream         3          314.36        943.08         Wallet
# 991        Dupatta         2           41.98         83.96    Credit Card
# 992      Body Wash         2           94.53        189.06            UPI
# 993      Dumbbells        10          441.41       4414.10    Credit Card
# 994       Bean Bag         3          448.43       1345.29           Cash
# 995     Board Game         7          474.27       3319.89            UPI
# 996       Leggings         7          437.77       3064.39         Wallet
# 997  Plastic Stool         1          278.20        278.20           Cash
# 998         Marker         8          260.94       2087.52         Wallet
# 999       Utensils         7           89.96        629.72           Cash
#
#     Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 990       2025-04-13                20        754.46               No
# 991       2025-02-05                20         67.17              Yes
# 992       2025-06-27                20        151.25              Yes
# 993       2024-07-01                 0       4414.10               No
# 994       2024-08-21                 5       1278.03               No
# 995       2024-07-16                20       2655.91               No
# 996       2024-08-16                 5       2911.17              Yes
# 997       2025-06-06                20        222.56              Yes
# 998       2025-06-13                10       1878.77              Yes
# 999       2024-12-23                10        566.75               No

# %%
df.head()
# Out:
#   Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0     BB1001     CUST583    Male   21  Ahmedabad        Household
# 1     BB1002     CUST766    Male   41  Bangalore        Furniture
# 2     BB1003     CUST285    Male   64      Surat        Groceries
# 3     BB1004     CUST381  Female   30     Nagpur      Electronics
# 4     BB1005     CUST979    Male   63       Pune           Sports
#
#   Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0      Doormat        10          224.45       2244.50           Cash
# 1        Table         2          270.05        540.10    Credit Card
# 2       Paneer         9          436.59       3929.31            UPI
# 3   Power Bank         6          254.36       1526.16         Wallet
# 4    Dumbbells         2          262.23        524.46         Wallet
#
#   Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 0       2025-05-06                10       2020.05               No
# 1       2025-04-04                15        459.08              Yes
# 2       2024-12-01                20       3143.45               No
# 3       2024-10-03                15       1297.24               No
# 4       2025-01-04                 5        498.24              Yes

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Invoice_ID        1000 non-null   object
#  1   Customer_ID       1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   City              1000 non-null   object
#  5   Product_Category  1000 non-null   object
#  6   Product_Name      1000 non-null   object
#  7   Quantity          1000 non-null   int64
#  8   Price_Per_Unit    1000 non-null   float64
#  9   Total_Amount      1000 non-null   float64
#  10  Payment_Method    1000 non-null   object
#  11  Date_of_Purchase  1000 non-null   object
#  12  Discount_Percent  1000 non-null   int64
#  13  Final_Amount      1000 non-null   float64
#  14  Loyalty_Customer  1000 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 117.3+ KB

# %%
df.columns
# Out:
# Index(['Invoice_ID', 'Customer_ID', 'Gender', 'Age', 'City',
#        'Product_Category', 'Product_Name', 'Quantity', 'Price_Per_Unit',
#        'Total_Amount', 'Payment_Method', 'Date_of_Purchase',
#        'Discount_Percent', 'Final_Amount', 'Loyalty_Customer'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Invoice_ID           object
# Customer_ID          object
# Gender               object
# Age                   int64
# City                 object
# Product_Category     object
# Product_Name         object
# Quantity              int64
# Price_Per_Unit      float64
# Total_Amount        float64
# Payment_Method       object
# Date_of_Purchase     object
# Discount_Percent      int64
# Final_Amount        float64
# Loyalty_Customer     object
# dtype: object

# %%
df.City
# Out:
# 0      Ahmedabad
# 1      Bangalore
# 2          Surat
# 3         Nagpur
# 4           Pune
#          ...
# 995      Lucknow
# 996       Bhopal
# 997       Nagpur
# 998    Hyderabad
# 999        Thane
# Name: City, Length: 1000, dtype: object

# %%
df.Total_Amount.min()
# Out:
# 21.59

# %%
df.Quantity.sum()
# Out:
# np.int64(5495)

# %%
col=['Customer_ID','Gender','Age']
df[col]
# Out:
#     Customer_ID  Gender  Age
# 0       CUST583    Male   21
# 1       CUST766    Male   41
# 2       CUST285    Male   64
# 3       CUST381  Female   30
# 4       CUST979    Male   63
# ..          ...     ...  ...
# 995     CUST332  Female   36
# 996     CUST327    Male   36
# 997     CUST709    Male   55
# 998     CUST943    Male   45
# 999     CUST799    Male   45
#
# [1000 rows x 3 columns]

# %%
df.iloc[8:50]
# Out:
#    Invoice_ID Customer_ID  Gender  Age        City Product_Category  \
# 8      BB1009     CUST935  Female   58       Delhi       Stationery
# 9      BB1010     CUST192    Male   36  Chandigarh        Household
# 10     BB1011     CUST996  Female   36      Jaipur           Beauty
# 11     BB1012     CUST993  Female   51       Surat       Stationery
# 12     BB1013     CUST920  Female   19   Bangalore        Household
# 13     BB1014     CUST942    Male   34  Chandigarh     Toys & Games
# 14     BB1015     CUST205    Male   46       Patna          Kitchen
# 15     BB1016     CUST924  Female   47       Thane      Electronics
# 16     BB1017     CUST347  Female   54     Chennai       Stationery
# 17     BB1018     CUST449  Female   36       Delhi          Kitchen
# 18     BB1019     CUST579    Male   48      Nagpur       Stationery
# 19     BB1020     CUST336    Male   29   Ahmedabad        Furniture
# 20     BB1021     CUST780  Female   25      Ranchi      Electronics
# 21     BB1022     CUST492  Female   60   Ahmedabad        Groceries
# 22     BB1023     CUST685  Female   42   Bangalore       Stationery
# 23     BB1024     CUST691    Male   52     Chennai        Furniture
# 24     BB1025     CUST702  Female   63   Bangalore           Beauty
# 25     BB1026     CUST890  Female   55      Ranchi          Apparel
# 29          Table         3          341.80       1025.40           Cash
# 31            Mop         5          440.20       2201.00            UPI
# ..            ...       ...             ...           ...            ...
# 895  Coloring Kit         1          427.55        427.55            UPI
# 913   Rolling Pin         1          364.03        364.03    Credit Card
# 929         Chair         4           87.90        351.60            UPI
# 939        Puzzle         9          320.68       2886.12    Credit Card
# 949         Chair         2          393.43        786.86           Cash
#
#     Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 0         2025-05-06                10       2020.05               No
# 7         2024-10-20                20       1368.40               No
# 12        2024-10-12                10       2209.28              Yes
# 29        2025-06-19                10        922.86               No
# 31        2025-05-13                 5       2090.95              Yes
# ..               ...               ...           ...              ...
# 895       2024-11-18                10        384.80              Yes
# 913       2025-05-04                 0        364.03               No
# 929       2024-10-01                10        316.44               No
# 939       2024-11-08                 5       2741.81              Yes
# 949       2025-04-09                 5        747.52              Yes
#
# [121 rows x 15 columns]

# %%
game1 = df.Gender == 'male'
df[game1]
# Out:
# Empty DataFrame
# Columns: [Invoice_ID, Customer_ID, Gender, Age, City, Product_Category, Product_Name, Quantity, Price_Per_Unit, Total_Amount, Payment_Method, Date_of_Purchase, Discount_Percent, Final_Amount, Loyalty_Customer]
# Index: []

# %%
df.sort_values(by='Age')
# Out:
#     Invoice_ID Customer_ID  Gender  Age        City Product_Category  \
# 518     BB1519     CUST868  Female   18  Chandigarh        Groceries
# 477     BB1478     CUST163  Female   18   Bangalore          Kitchen
# 685     BB1686     CUST776    Male   18   Ahmedabad        Furniture
# 715     BB1716     CUST661    Male   18     Lucknow        Furniture
# 723     BB1724     CUST347  Female   18       Thane       Stationery
# ..         ...         ...     ...  ...         ...              ...
# 748     BB1749     CUST102  Female   65     Kolkata        Household
# 127     BB1128     CUST751  Female   65      Nagpur          Apparel
# 824     BB1825     CUST833  Female   65      Bhopal          Kitchen
# 48      BB1049     CUST857  Female   65      Mumbai          Apparel
# 721     BB1722     CUST471    Male   65    Vadodara          Kitchen
#
#            Product_Name  Quantity  Price_Per_Unit  Total_Amount  \
# 518               Bread         4          129.67        518.68
# 477         Rolling Pin         5           77.56        387.80
# 685          Sofa Cover         7          486.26       3403.82
# 715  Wardrobe Organizer         7          488.38       3418.66
# 723                 Pen         7          412.89       2890.23
# ..                  ...       ...             ...           ...
# 748                 Mop         1          124.34        124.34
# 127         Track Pants         9          176.46       1588.14
# 824       Cutting Board         9          227.50       2047.50
# 48               Jacket         8          431.41       3451.28
# 721          Tiffin Box         9          114.64       1031.76
#
#     Payment_Method Date_of_Purchase  Discount_Percent  Final_Amount  \
# 518            UPI       2024-08-11                 5        492.75
# 477            UPI       2025-04-12                10        349.02
# 685    Credit Card       2024-12-10                20       2723.06
# 715           Cash       2025-06-07                 5       3247.73
# 723    Credit Card       2024-07-02                 0       2890.23
# ..             ...              ...               ...           ...
# 748            UPI       2024-10-23                10        111.91
# 127    Credit Card       2024-09-06                 0       1588.14
# 824         Wallet       2024-08-17                 5       1945.12
# 48     Credit Card       2024-09-26                 5       3278.72
# 721            UPI       2024-07-17                 0       1031.76
#
#     Loyalty_Customer
# 518              Yes
# 477              Yes
# 685               No
# 715              Yes
# 723               No
# ..               ...
# 748               No
# 127              Yes
# 824              Yes
# 48                No
# 721              Yes
#
# [1000 rows x 15 columns]

# %%
df["Phone"] = 160923750018

# %%
df.head(5)
# Out:
#   Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0     BB1001     CUST583    Male   21  Ahmedabad        Household
# 1     BB1002     CUST766    Male   41  Bangalore        Furniture
# 2     BB1003     CUST285    Male   64      Surat        Groceries
# 3     BB1004     CUST381  Female   30     Nagpur      Electronics
# 4     BB1005     CUST979    Male   63       Pune           Sports
#
#   Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0      Doormat        10          224.45       2244.50           Cash
# 1        Table         2          270.05        540.10    Credit Card
# 2       Paneer         9          436.59       3929.31            UPI
# 3   Power Bank         6          254.36       1526.16         Wallet
# 4    Dumbbells         2          262.23        524.46         Wallet
#
#   Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer  \
# 0       2025-05-06                10       2020.05               No
# 1       2025-04-04                15        459.08              Yes
# 2       2024-12-01                20       3143.45               No
# 3       2024-10-03                15       1297.24               No
# 4       2025-01-04                 5        498.24              Yes
#
#           Phone
# 0  160923750018
# 1  160923750018
# 2  160923750018
# 3  160923750018
# 4  160923750018

# %%
df.tail()
# Out:
#     Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 995     BB1996     CUST332  Female   36    Lucknow     Toys & Games
# 996     BB1997     CUST327    Male   36     Bhopal          Apparel
# 997     BB1998     CUST709    Male   55     Nagpur        Furniture
# 998     BB1999     CUST943    Male   45  Hyderabad       Stationery
# 999     BB2000     CUST799    Male   45      Thane          Kitchen
#
#       Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 995     Board Game         7          474.27       3319.89            UPI
# 996       Leggings         7          437.77       3064.39         Wallet
# 997  Plastic Stool         1          278.20        278.20           Cash
# 998         Marker         8          260.94       2087.52         Wallet
# 999       Utensils         7           89.96        629.72           Cash
#
#     Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer  \
# 995       2024-07-16                20       2655.91               No
# 996       2024-08-16                 5       2911.17              Yes
# 997       2025-06-06                20        222.56              Yes
# 998       2025-06-13                10       1878.77              Yes
# 999       2024-12-23                10        566.75               No
#
#             Phone
# 995  160923750018
# 996  160923750018
# 997  160923750018
# 998  160923750018
# 999  160923750018

# %%
df.iloc[2]
# Out:
# Invoice_ID                BB1003
# Customer_ID              CUST285
# Gender                      Male
# Age                           64
# City                       Surat
# Product_Category       Groceries
# Product_Name              Paneer
# Quantity                       9
# Price_Per_Unit            436.59
# Total_Amount             3929.31
# Payment_Method               UPI
# Date_of_Purchase      2024-12-01
# Discount_Percent              20
# Final_Amount             3143.45
# Loyalty_Customer              No
# Phone               160923750018
# Name: 2, dtype: object

# %%
df.groupby('Gender')['Total_Amount'].sum()
# Out:
# Gender
# Female    714342.93
# Male      729178.66
# Name: Total_Amount, dtype: float64

# %%
df.groupby('City')['Total_Amount'].sum().sort_values()#,ascending=False
# Out:
# City
# Vadodara         51914.47
# Patna            55694.12
# Kolkata          55993.41
# Indore           59069.39
# Visakhapatnam    61454.90
# Mumbai           62935.40
# Pune             67312.01
# Ahmedabad        68796.72
# Bhopal           70957.91
# Nagpur           72012.45
# Hyderabad        72492.13
# Surat            73373.01
# Chandigarh       73958.50
# Ranchi           75062.80
# Delhi            75658.76
# Jaipur           84470.16
# Bangalore        86591.46
# Lucknow          87754.81
# Chennai          89858.33
# Thane            98160.85
# Name: Total_Amount, dtype: float64

# %%
df.groupby('Gender')["Age"].sum()
# Out:
# Gender
# Female    20374
# Male      21134
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt
year = [2011,2012,2013,2014,2015]
population = [12000,13000,14000,15000,16500]
plt.plot(year,population)
plt.xlabel("Years")
plt.ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %%
size = ['S','M','L','XL']
qty =[24,34,12,9]
plt.bar(size,qty)
plt.title("t-shirt")
plt.xlabel("qty")
plt.ylabel("size")
# Out:
# Text(0, 0.5, 'size')

# %%
age = [30,20,40,50,60,70,80,92]
plt.hist(age)
plt.xlabel("age")
# Out:
# Text(0.5, 0, 'age')

# %%
import numpy as np
data = np.random.randint(1,100,1000)
plt.hist(data,bins=25)
# Out:
# (array([39., 37., 30., 45., 34., 39., 44., 39., 47., 37., 24., 41., 31.,
#         45., 51., 36., 36., 53., 41., 38., 38., 42., 45., 45., 43.]),
#  array([ 1.  ,  4.92,  8.84, 12.76, 16.68, 20.6 , 24.52, 28.44, 32.36,
#         36.28, 40.2 , 44.12, 48.04, 51.96, 55.88, 59.8 , 63.72, 67.64,
#         71.56, 75.48, 79.4 , 83.32, 87.24, 91.16, 95.08, 99.  ]),
#  <BarContainer object of 25 artists>)

# %%
size = ['S','M','L','XL']
qty =[24,34,12,9]
plt.pie(qty,labels=size, autopct="%1.2f%%");
plt.title("T-shirt size Distribution")

# %% [markdown]
# seaborn

# %%
import seaborn as sns
df1=sns.load_dataset("flights")
df1
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(x="year",y="passengers",data=df1)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
import seaborn as sns
df2=sns.load_dataset("tips")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="day",y="total_bill",data=df2)
plt.xlabel("day")
plt.ylabel("total_bill")
# Out:
# Text(0, 0.5, 'total_bill')

# %%
sns.countplot(x="day",data=df2)
df2
plt.xlabel("day")
plt.ylabel("total_bill")
# Out:
# Text(0, 0.5, 'total_bill')

# %%
sns.boxplot(x="day",y="total_bill",data=df2)
plt.xlabel("day")
plt.ylabel("total_bill")
# Out:
# Text(0, 0.5, 'total_bill')

# %%
df3=sns.load_dataset("iris")
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x="sepal_length",y="petal_length",data=df3)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.pairplot(df3)

# %%
sns.pairplot(df2)

# %%
sns.pairplot(df1)

# %%
sns.barplot(x="day",y="total_bill",hue="sex",data=df2)
plt.xlabel("day")
plt.ylabel("total_bill")
# Out:
# Text(0, 0.5, 'total_bill')
